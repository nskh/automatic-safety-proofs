# %%
import sys, os
sys.path.append(os.path.abspath(".."))

from sympy import *
from safe_region_utils import *

# %%
init_printing()


x, y = symbols("x y")
w = 0.1
square_points: list = [
    geometry.Point(val) for val in [[w, -w], [w, w], [-w, w], [-w, -w]]
]
square: geometry.Polygon = Polygon(*square_points)
print("Plotting object. Close plot to continue example...\n")
plot_polygon(square)

# traj_piecewise = Piecewise(
#     (1.63071 - 0.00139893*x, (x >= 0) & (x <= 120)),
#     (1.63016 - 0.00139435*x, (x > 120) & (x <= 180)),
#     (nan, True)  # undefined outside
# )
# traj_piecewise = Piecewise((1.54677, x <= 60.0), (1.63071 - x, (x > 60) & (x <= 120)))#, (1.63016 - 0.00139435*x, (x >= 120) & (x < 180)), (1.62933 - 0.00138975*x, (x >= 180.0) & (x < 240.0)), (1.62823 - 0.00138514*x, (x >= 240.0) & (x <= 300.0)))
#                         #    (1.62684 - 0.00138051*x, (x >= 300.0) & (x < 360.0)), (1.62516 - 0.00137586*x, (x >= 360.0) & (x < 420.0)), (1.6232 - 0.00137119*x, (x >= 420.0) & (x < 480.0)), (1.62095 - 0.00136651*x, (x >= 480.0) & (x <= 540.0)))
                        #    (1.61841 - 0.00136181*x, (x >= 540.0) & (x < 600.0)), (1.61558 - 0.00135708*x, (x >= 600.0) & (x < 660.0)), (1.61245 - 0.00135235*x, (x >= 660.0) & (x < 720.0)), (1.60903 - 0.00134759*x, (x >= 720.0) & (x < 780.0)), 
                        #    (1.60531 - 0.00134282*x, (x >= 780.0) & (x < 840.0)), (1.60128 - 0.00133803*x, (x >= 840.0) & (x < 900.0)), (1.59696 - 0.00133322*x, (x >= 900.0) & (x < 960.0)), (1.59232 - 0.00132839*x, (x >= 960.0) & (x < 1020.0)), 
                        #    (1.58738 - 0.00132355*x, (x >= 1020.0) & (x < 1080.0)), (1.58213 - 0.00131869*x, (x >= 1080.0) & (x < 1140.0)), (1.57658 - 0.00131381*x, (x >= 1140.0) & (x <= 1200.0)), (nan, True))

# traj_piecewise = Piecewise((0.235477*x - 133.081, (x >= 0.0) & (x < 60.0)), (0.235477*x - 133.081, (x >= 60.0) & (x < 120.0)), (0.235477*x - 133.081, (x >= 120.0) & (x < 180.0)), (0.235477*x - 133.081, (x >= 180.0) & (x <= 240.0)))
                        #    (0.235477*x - 133.081, (x >= 240.0) & (x < 300.0)), (0.235477*x - 133.081, (x >= 300.0) & (x < 360.0)), (0.235477*x - 133.081, (x >= 360.0) & (x < 420.0)), (0.235477*x - 133.081, (x >= 420.0) & (x < 480.0)), 
                        #    (0.235477*x - 133.081, (x >= 480.0) & (x < 540.0)), (0.235477*x - 133.081, (x >= 540.0) & (x < 600.0)), (0.235477*x - 133.081, (x >= 600.0) & (x < 660.0)), (0.235477*x - 133.081, (x >= 660.0) & (x < 720.0)), 
                        #    (0.235477*x - 133.081, (x >= 720.0) & (x < 780.0)), (0.235477*x - 133.081, (x >= 780.0) & (x < 840.0)), (0.235477*x - 133.081, (x >= 840.0) & (x < 900.0)), (0.235477*x - 133.081, (x >= 900.0) & (x < 960.0)), 
                        #    (0.235477*x - 133.081, (x >= 960.0) & (x < 1020.0)), (0.235477*x - 133.081, (x >= 1020.0) & (x < 1080.0)), (0.235477*x - 133.081, (x >= 1080.0) & (x < 1140.0)), (0.235478*x - 133.082, (x >= 1140.0) & (x <= 1200.0)))

# Piecewise((443550.0 - 11708.4*x, (x < 1.0) & (x >= 0)), (441557.0 - 9715.13*x, (x >= 1.0) & (x < 2.0)), (441557.0 - 9715.19*x, (x >= 2.0) & (x < 3.0))) 
#         #   (446627.0 - 11405.0*x, (x >= 3.0) & (x < 4.0)), (446699.0 - 11423.0*x, (x >= 4.0) & (x < 5.0)), (446788.0 - 11440.9*x, (x >= 5.0) & (x < 6.0)), 
#         #   (446896.0 - 11458.9*x, (x >= 6.0) & (x < 7.0)), (447021.0 - 11476.8*x, (x >= 7.0) & (x < 8.0)), (447164.0 - 11494.7*x, (x >= 8.0) & (x < 9.0)), 
#         #   (447326.0 - 11512.6*x, (x >= 9.0) & (x < 10.0)), (447503.0 - 11530.4*x, (x >= 10.0) & (x < 11.0)), (447700.0 - 11548.3*x, (x >= 11.0) & (x < 12.0)), 
#         #   (447914.0 - 11566.1*x, (x >= 12.0) & (x < 13.0)), (448144.0 - 11583.8*x, (x >= 13.0) & (x < 14.0)), (448393.0 - 11601.6*x, (x >= 14.0) & (x < 15.0)), 
#         #   (448659.0 - 11619.3*x, (x >= 15.0) & (x < 16.0)), (448942.0 - 11637.0*x, (x >= 16.0) & (x < 17.0)), (449243.0 - 11654.7*x, (x >= 17.0) & (x < 18.0)), 
#         #   (449561.0 - 11672.3*x, (x >= 18.0) & (x < 19.0)), (449896.0 - 11690.0*x, (x >= 19.0) & (x < 20.0)), (450249.0 - 11707.6*x, (x >= 20.0) & (x < 21.0)), 
#         #   (450618.0 - 11725.2*x, (x >= 21.0) & (x < 22.0)), (451005.0 - 11742.8*x, (x >= 22.0) & (x < 23.0)), (451408.0 - 11760.3*x, (x >= 23.0) & (x < 24.0)), 
#         #   (451828.0 - 11777.8*x, (x >= 24.0) & (x < 25.0)), (452266.0 - 11795.3*x, (x >= 25.0) & (x < 26.0)), (297773.0 - 5853.31*x, (x >= 26.0) & (x <= 27.0)))

# traj_piecewise = Piecewise((1.54677, x <= 60.0), (1.63071 - 0.00139893*x, x <= 120.0), (0, True))
# traj_piecewise = 1.63071 - 0.00139893*x
# Out:
# Plotting object. Close plot to continue example...

# %%
# traj_piecewise = Piecewise((-2.38529, ((x >= 2.0) | (x < 1.0) | (x < 2.0)) & ((x < 1.0) | (x < 2.0) | (x < 3.0)) & ((x >= 1.0) | (x >= 2.0) | (x >= 0)) & ((x >= 1.0) | (x < 3.0) | (x >= 0)) & ((x >= 2.0) | (x < 2.0) | (x >= 0)) & ((x < 2.0) | (x < 3.0) | (x >= 0))), 
#           (0.121269*x - 2.7491, (x >= 3.0) & (x < 26.0)),
#         (0.0464082*x - 0.802721, (x >= 26.0) & (x <= 27.0)))

# traj_piecewise = Piecewise((-2.38529, (x >= 0.0) & (x < 1.0)), (-2.38529, (x >= 1.0) & (x < 2.0)), (-2.38529, (x >= 2.0) & (x < 3.0)), (0.121269*x - 2.7491, (x >= 3.0) & (x < 4.0)), (0.121269*x - 2.7491, (x >= 4.0) & (x < 5.0)), (0.121269*x - 2.7491, (x >= 5.0) & (x < 6.0)), (0.121269*x - 2.7491, (x >= 6.0) & (x < 7.0)), (0.121269*x - 2.7491, (x >= 7.0) & (x < 8.0)), (0.121269*x - 2.7491, (x >= 8.0) & (x < 9.0)), (0.121269*x - 2.7491, (x >= 9.0) & (x < 10.0)), (0.121269*x - 2.7491, (x >= 10.0) & (x < 11.0)), (0.121269*x - 2.7491, (x >= 11.0) & (x < 12.0)), (0.121269*x - 2.7491, (x >= 12.0) & (x < 13.0)), (0.121269*x - 2.7491, (x >= 13.0) & (x < 14.0)), (0.121269*x - 2.7491, (x >= 14.0) & (x < 15.0)), (0.121269*x - 2.7491, (x >= 15.0) & (x < 16.0)), (0.121269*x - 2.7491, (x >= 16.0) & (x < 17.0)), (0.121269*x - 2.7491, (x >= 17.0) & (x < 18.0)), (0.121269*x - 2.7491, (x >= 18.0) & (x < 19.0)), (0.121269*x - 2.7491, (x >= 19.0) & (x < 20.0)), (0.121269*x - 2.7491, (x >= 20.0) & (x < 21.0)), (0.121269*x - 2.7491, (x >= 21.0) & (x < 22.0)), (0.121269*x - 2.7491, (x >= 22.0) & (x < 23.0)), (0.121269*x - 2.7491, (x >= 23.0) & (x < 24.0)), (0.121269*x - 2.7491, (x >= 24.0) & (x < 25.0)), (0.121269*x - 2.7491, (x >= 25.0) & (x < 26.0)), (0.0464082*x - 0.802721, (x >= 26.0) & (x <= 27.0)))
traj_piecewise_lat = Piecewise((-2.385292, (x < 3.0) & (x >= 0)), (0.121268860507243*x - 2.74909858152173, (x >= 3.0) & (x < 26.0)), (0.0464082083333324*x - 0.802721624999975, (x >= 26.0) & (x <= 27.0)))
traj_piecewise_lon = Piecewise((5.45517099999999 - 0.144000000000005*x, (x < 1.0) & (x >= 0)), (5.43065649999997 - 0.119485499999982*x, (x >= 1.0) & (x < 3.0)), (5.50420000000004 - 0.144000000000005*x, (x >= 3.0) & (x < 26.0)), (3.63220000000007 - 0.0720000000000027*x, (x >= 26.0) & (x <= 27.0)))
traj_piecewise_alt = Piecewise((-7000.0, (x < 1.0) & (x >= 0)), (1000.0*x - 8000.0, (x >= 1.0) & (x < 2.0)), (-6000.0, (x >= 2.0) & (x < 3.0)), (1000.0*x - 9000.0, (x >= 3.0) & (x < 4.0)), (-5000.0, (x >= 4.0) & (x < 20.0)), (1000.0*x - 25000.0, (x >= 20.0) & (x < 21.0)), (-4000.0, (x >= 21.0) & (x < 26.0)), (1000.0*x - 30000.0, (x >= 26.0) & (x <= 27.0)))
print("Plotting trajectory. Close plot to continue example...\n")
plot(traj_piecewise_lat, (x, 0, 27))
plot(traj_piecewise_lon, (x, 0, 27))
plot(traj_piecewise_alt, (x, 0, 27))
# Out:
# Plotting trajectory. Close plot to continue example...

# %%
domain_lat = Interval(-8,30)
xbounds_lat = [0, 27]
ybounds_lat = [-3, 2]
# domain = Interval(-10, 240)
# xbounds = [0, 240]
# ybounds = [-150, -60]
example_name = "Relative trajectory of an aircraft wro another aircraft"

cond_lat = compute_unsafe_cond(
    x,
    y,
    square,
    traj_piecewise_lat,
    domain_lat,
)
print("Boolean condition for unsafe region:\n", cond_lat)
# Out:
# solveset solution: EmptySet
# solveset solution: EmptySet
# solveset solution: EmptySet
# solveset solution: EmptySet
# solveset solution: EmptySet
# solveset solution: EmptySet
# solveset solution: EmptySet
# solveset solution: EmptySet
# solveset solution: EmptySet
# solveset solution: EmptySet
# Line2D(Point2D(3, -596323/250000), Point2D(31/10, -621323/250000))
# 1/10 x 1/10 y -153677/2500000
# Line2D(Point2D(26, 403891791666667/1000000000000000), Point2D(261/10, 303891791666667/1000000000000000))
# 1/10 x 1/10 y -26403891791666667/10000000000000000
# Line2D(Point2D(26, 403891791666667/1000000000000000), Point2D(261/10, 303891791666667/1000000000000000))
# 1/10 x 1/10 y -26403891791666667/10000000000000000
# current_piece []
# Line2D(Point2D(27, 4503/10000), Point2D(271/10, 3503/10000))
# 1/10 x 1/10 y -274503/100000
# Boolean condition for unsafe region:
# ...

# %%
print(
    "\nPlotting dot grid visualization of safe and unsafe regions. This may take up to 20 seconds to plot.\nOnce displayed, close plot to continue example...\n"
)
plot_condition(x, y, cond_lat, xbounds_lat, ybounds_lat, title=example_name)
mathematica_output = print_mathematica(
    x, y, cond_lat, xbounds_lat, ybounds_lat, traj_piecewise_lat, square
)
print("Mathematica command for plotting:\n", mathematica_output)
# Out:
# Plotting dot grid visualization of safe and unsafe regions. This may take up to 20 seconds to plot.
# Once displayed, close plot to continue example...
# Mathematica command for plotting:
#
# Show[
# ...

# %%
domain_lon = Interval(-8,30)
xbounds_lon = [0, 27]
ybounds_lon = [0, 6]
# domain = Interval(-10, 240)
# xbounds = [0, 240]
# ybounds = [-150, -60]
example_name = "Relative trajectory of an aircraft wro another aircraft lon"

cond_lon = compute_unsafe_cond(
    x,
    y,
    square,
    traj_piecewise_lon,
    domain_lon,
)
print("Boolean condition for unsafe region:\n", cond_lon)
# Out:
# solveset solution: EmptySet
# solveset solution: EmptySet
# solveset solution: EmptySet
# solveset solution: EmptySet
# solveset solution: EmptySet
# solveset solution: EmptySet
# solveset solution: EmptySet
# solveset solution: EmptySet
# solveset solution: EmptySet
# solveset solution: EmptySet
# solveset solution: EmptySet
# solveset solution: EmptySet
# solveset solution: EmptySet
# solveset solution: EmptySet
# solveset solution: EmptySet
# solveset solution: EmptySet
# Line2D(Point2D(1, 531117099999999/100000000000000), Point2D(9/10, 521117099999999/100000000000000))
# 1/10 x -1/10 y 431117099999999/1000000000000000
# Line2D(Point2D(3, 507220000000003/100000000000000), Point2D(29/10, 497220000000003/100000000000000))
# 1/10 x -1/10 y 207220000000003/1000000000000000
# Line2D(Point2D(3, 507220000000003/100000000000000), Point2D(29/10, 497220000000003/100000000000000))
# 1/10 x -1/10 y 207220000000003/1000000000000000
# current_piece []
# ...

# %%
print(
    "\nPlotting dot grid visualization of safe and unsafe regions. This may take up to 20 seconds to plot.\nOnce displayed, close plot to continue example...\n"
)
plot_condition(x, y, cond_lon, xbounds_lon, ybounds_lon, title=example_name)
mathematica_output = print_mathematica(
    x, y, cond_lon, xbounds_lon, ybounds_lon, traj_piecewise_lon, square
)
print("Mathematica command for plotting:\n", mathematica_output)
# Out:
# Plotting dot grid visualization of safe and unsafe regions. This may take up to 20 seconds to plot.
# Once displayed, close plot to continue example...
# Mathematica command for plotting:
#
# Show[
# ...

# %%
domain_alt = Interval(-8,30)
xbounds_alt = [0, 27]
ybounds_alt = [-7000, -3000]
# domain = Interval(-10, 240)
# xbounds = [0, 240]
# ybounds = [-150, -60]

w = 500
square_points: list = [
    geometry.Point(val) for val in [[w, -w], [w, w], [-w, w], [-w, -w]]
]
square: geometry.Polygon = Polygon(*square_points)
example_name = "Relative trajectory of an aircraft wro another aircraft alt"

cond_alt = compute_unsafe_cond(
    x,
    y,
    square,
    traj_piecewise_alt,
    domain_alt,
)
print("Boolean condition for unsafe region:\n", cond_alt)
# Out:
# solveset solution: EmptySet
# solveset solution: EmptySet
# solveset solution: EmptySet
# solveset solution: EmptySet
# solveset solution: EmptySet
# solveset solution: EmptySet
# solveset solution: EmptySet
# solveset solution: EmptySet
# solveset solution: EmptySet
# solveset solution: EmptySet
# solveset solution: EmptySet
# solveset solution: EmptySet
# solveset solution: EmptySet
# solveset solution: EmptySet
# solveset solution: EmptySet
# solveset solution: EmptySet
# solveset solution: EmptySet
# solveset solution: EmptySet
# solveset solution: EmptySet
# solveset solution: EmptySet
# solveset solution: EmptySet
# solveset solution: EmptySet
# solveset solution: EmptySet
# solveset solution: EmptySet
# Line2D(Point2D(1, -7000), Point2D(501, -7500))
# 500 x 500 y 3499500
# Line2D(Point2D(2, -6000), Point2D(502, -6500))
# 500 x 500 y 2999000
# Line2D(Point2D(3, -6000), Point2D(503, -6500))
# 500 x 500 y 2998500
# Line2D(Point2D(4, -5000), Point2D(504, -5500))
# ...

# %%
plot_condition(x, y, cond_alt, xbounds_alt, ybounds_alt, title=example_name, resolution=10)
mathematica_output = print_mathematica(
    x, y, cond_alt, xbounds_alt, ybounds_alt, traj_piecewise_alt, square
)
print("Mathematica command for plotting:\n", mathematica_output)
# Out:
# Mathematica command for plotting:
#
# Show[
# ...

# %%
x = 120
y = 1.63071 - x
b=((x >= 599/10) & (x <= 601/10) & ((y - 1.64677)*(y - 1.44677) <= 0) & ((x/10 + y/10 - 6154677/1000000)**2 <= 0)) | ((x >= -101/10) & (x <= 601/10) & ((y - 1.64677)*(y - 1.44677) <= 0) & ((x/10 + y/10 - 6154677/1000000)*(x/10 + y/10 + 845323/1000000) <= 0)) | ((x >= 599/10) & (x <= 1201/10) & ((x/10 - y/10 - 23836929/1000000)*(x/10 - y/10 - 5845323/1000000) <= 0) & ((y - Piecewise((1.54677, x < 599/10), (1.53071 - x, x <= 1199/10), (-118.36929, True)) + 1/10)*(y - Piecewise((1.54677, x < 601/10), (1.73071 - x, x <= 1201/10), (-118.36929, True)) - 1/10) <= 0))

# %%
b
# Out:
# True

# %%
x = 2.2
y = -2.38529
c =((x >= 29/10) & (x <= 31/10) & ((x/10 + y/10 - 614707/10000000)**2 <= 0) & ((y - Piecewise((-2.385293, x < 29/10), (-2.38529, x <= 29/10), (-2.385293, True)) - 1/10)*(y - Piecewise((-2.385293, x < 31/10), (-2.38529, x <= 31/10), (-2.385293, True)) + 1/10) <= 0)) | ((x >= -1/10) & (x <= 31/10) & ((x/10 + y/10 - 614707/10000000)*(x/10 + y/10 + 238529/1000000) <= 0) & ((y - Piecewise((-2.38529, (x <= 29/10) | (x < -1/10)), (-2.385293, True)) - 1/10)*(y - Piecewise((-2.38529, (x <= 31/10) | (x < 1/10)), (-2.385293, True)) + 1/10) <= 0)) | ((x >= 29/10) & (x <= 71/10) & ((x/10 + y/10 - 5099783/10000000)*(x/10 + y/10 - 614707/10000000) <= 0) & ((y - Piecewise((-2.385293, x < 29/10), (0.121269*x - 2.7369731, x <= 69/10), (-1.900217, True)) - 1/10)*(y - Piecewise((-2.385293, x < 31/10), (0.121269*x - 2.7612269, x <= 71/10), (-1.900217, True)) + 1/10) <= 0))

# %%
c
# Out:
# True
